# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="r-ent"):
    print(d.find(class_="title").text.replace('\t', '').replace('\n', ''))
    print(d.find(class_="author").text, '\t', d.find(class_='date').text)
    print('-------------------------------------------')
# Out:
# [BOX ] Kings 113:118 Heat
# guardyo 	  1/21
# -------------------------------------------
# [Live] 金塊 @ 灰狼
# thnlkj0665 	  1/21
# -------------------------------------------
# [情報] 76人跟湖人對Rose有興趣
# dragon803 	  1/21
# -------------------------------------------
# Re: [BOX ] Thunder 112:107 Rockets
# JRSmith 	  1/21
# -------------------------------------------
# [情報] 在今晚三分1-17後 鬍子賽後加練
# pneumo 	  1/21
# -------------------------------------------
# [Live] 馬刺 @ 太陽
# thnlkj0665 	  1/21
# -------------------------------------------
# [新聞] NBA／保羅砍28分宰前東家 雷霆賞火箭四連
# rainandwind 	  1/21
# -------------------------------------------
# [情報] Walker拿下對Lebron的生涯首勝
# melman87 	  1/21
# -------------------------------------------
# [BOX ] Lakers 107:139 Celtics
# guardyo 	  1/21
# -------------------------------------------
# [Live] 勇士 @ 拓荒者
# thnlkj0665 	  1/21
# -------------------------------------------
# [BOX ] Nuggets 107:100 Timberwolves
# guardyo 	  1/21
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
try:
    old_soup = BeautifulSoup(requests.get('https://www.ptt.cc' + soup.find(class_='btn wide')['href']).text, "html5lib")
    for d in old_soup.find_all(class_="r-ent"):
        print(d.find(class_="title").text.replace('\t', '').replace('\n', ''))
        print(d.find(class_="author").text, '\t', d.find(class_='date').text)
        print('-------------------------------------------')
except:
    pass
# Out:
# [轉錄]Lyotard 對於太陽板討論串的結論
# Price 	  5/16
# -------------------------------------------
# [公告] 請停止一切關於本次活動的發言
# Price 	  5/31
# -------------------------------------------
# [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# Frankaze 	  6/08
# -------------------------------------------
# [轉錄]再轉一篇好文來
# Frankaze 	  6/08
# -------------------------------------------
# [轉錄][情報] 夏洛特山貓系列
# Price 	  6/10
# -------------------------------------------
# [轉錄]Re: [心得] 真是受不了糗爺....
# Price 	  6/10
# -------------------------------------------
# [轉錄]總冠軍賽NO.2觀後感
# Price 	  6/10
# -------------------------------------------
# [心得] Rasheed Wallace
# AmuroNamie 	  6/11
# -------------------------------------------
# 掌控球賽的男人
# toptree 	  6/12
# -------------------------------------------
# [閒聊] 說說2004季後賽名場面回顧
# skchang 	  6/12
# -------------------------------------------
# [心得] 其實說穿了 就是活塞的防守太可怕了
# shineup 	  6/12
# -------------------------------------------
# Re: [閒聊] 說說2004季後賽名場面回顧
# cOvi 	  6/12
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
url = 'https://www.ptt.cc/bbs/C_Chat/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text)

for d in soup.find_all(class_='r-ent'):
    print(d.find(class_='title').text.replace('\t', '').replace('\n', ''))
    print(d.find(class_="author").text, '\t', d.find(class_='date').text)
    print('-------------------------------------------')
# Out:
# [情報] 機動戰士鋼彈40週年 G40企劃 特別影片
# wl760713 	  1/21
# -------------------------------------------
# Re: [閒聊] 所謂後宮漫畫的結局？（金銀彼女）
# fragmentwing 	  1/21
# -------------------------------------------
# [問題] 過時的一廠大作還是沒辦法登上pc
# sevenzgod 	  1/21
# -------------------------------------------
# [閒聊] 碧藍航線-新船新skin
# chshsnail 	  1/21
# -------------------------------------------
# (本文已被刪除) [superRKO]
# - 	  1/21
# -------------------------------------------
# Re: [情報] 鬼滅之刃 東森電影台2/1 全台首播
# superRKO 	  1/21
# -------------------------------------------
# [閒聊] 小蘭跟和葉的適應能力是不是很差
# funsky 	  1/21
# -------------------------------------------
# (本文已被刪除) [gino861027]
# - 	  1/21
# -------------------------------------------
# [閒聊] 隱藏真名的超級英雄保險理賠嗎？
# SSZZ77 	  1/21
# -------------------------------------------
# Re: [閒聊] 作品的銷量是否可以決定神作的定義?
# Vinnie0605 	  1/21
# -------------------------------------------
# [女乃] 壓打~ 哞!
# MutsuKai 	  1/21
# -------------------------------------------
# [BGD] 動畫的六花之後會甩頭嗎
# ...
